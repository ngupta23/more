# %%
import pandas as pd
from more import viz_helper as vh

# %%
df = pd.read_csv("../data/titanic/train.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ### Basic Plotting

# %%
vh.plot_data(data = df[['Age','Fare','SibSp','Parch']])

# %%
vh.plot_data(data = df[['Sex','Embarked']], kind='count')

# %% [markdown]
# ### Plotting with Error Handling

# %%
vh.plot_data(data = df[['Age','Fare','SibSp','Parch','Sex','Embarked']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\more\viz_helper\plot_data.py:29: UserWarning: The data has categorical columns Index(['Sex', 'Embarked'], dtype='object') for which a distribution will not be plotted
#   warnings.warn("The data has categorical columns {} for which a distribution will not be plotted".format(cat_columns))

# %%
vh.plot_data(data = df[['Age','Fare','SibSp','Parch','Sex','Embarked']], kind='count')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\more\viz_helper\plot_data.py:34: UserWarning: The data has numeric columns Index(['Age', 'Fare', 'SibSp', 'Parch'], dtype='object') for which a count plot will not be plotted
#   warnings.warn("The data has numeric columns {} for which a count plot will not be plotted".format(num_columns))
